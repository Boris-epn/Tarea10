# %% [markdown]
# ## Conjunto de ejercicios

# %% [markdown]
# ### 1. Realice las siguientes multiplicaciones matriz-matriz

# %% [markdown]
# ![](tarea10.1.png)

# %% [markdown]
# #### a)

# %% [markdown]
# $$
# \begin{bmatrix}
# 2*1+(-3*2) & 2*5+(-3*0)\\
# 3*1+(-1*2) & 3*5+(-1*0)\\
# \end{bmatrix}
# =\begin{bmatrix}
# -4 & 10\\
# 1 & 15\\
# \end{bmatrix}$$

# %% [markdown]
# ### b)

# %% [markdown]
# $$
# \begin{bmatrix}
# 2*1+(-3*3) & 2*5+(-3*2) & 2*-4+(-3*0)\\
# 3*1+(-1*-3) & 3*5+(-1*2) & 3*-4+(-1*0)\\
# \end{bmatrix}=\begin{bmatrix}
# 11 & 4 & -8\\
# 6 & 13 & -12\\
# \end{bmatrix}
# $$

# %% [markdown]
# ### c)

# %% [markdown]
# $$
# \begin{bmatrix}
# 2*0+(-3*1)+(1*2) & 2*1+(-3*0)+(1*3) & 2*-2+(-3*-1)+(1*-2)\\
# 4*0+(3*1)+(0*2) & 4*1+(3*0)+(0*3) & 4*-2+(3*-1)+(0*-2)\\
# 5*0+(2*1)+(-4*2) & 5*1+(2*0)+(-4*3) & 5*-2+(2*-1)+(-4*-2)\\
# \end{bmatrix}
# $$
# $$
# =
# \begin{bmatrix}
# -1 & 5 & -3\\
# 3 & 4 & -11\\
# -6 & -7 & -4
# \end{bmatrix}
# $$

# %% [markdown]
# ### d)

# %% [markdown]
# $$
# \begin{bmatrix}
# 2*1+(1*-4)+(2*0) & 2*-2+(1*1)+(2*2)\\
# -2*1+(3*-4)+(0*0) & -2*-2+(3*1)+(0*2)\\
# 2*1+(-1*-4)+3*0 & 2*-2+(-1*1)+(3*2)\\
# \end{bmatrix}
# $$
# $$
# =
# \begin{bmatrix}
# -2 & 1\\
# -14 & 7\\
# 6 & 1\\
# \end{bmatrix}
# $$

# %% [markdown]
# ## 2.Determine cuáles de las siguientes matrices son no singulares y calcule la inversa de esas matrices:

# %% [markdown]
# ![](tarea10.2.png)

# %% [markdown]
# ### a)

# %% [markdown]
# Para conocer si una matriz es no singular primero calcularemos su determinante
# $$
# determinante=\\
# 4*0*-3+(2*7*-2)+(6*3*-1)-(2*0*-2)-(-1*4*4)-(-3*3*2)\\
# =0
# $$
# Por lo tanto la matriz es singular, y por ende no tiene una matriz inversa.

# %% [markdown]
# ### b)

# %% [markdown]
# Se puede determinar la matriz inversa a través del método de gauss Jordan
# $$
# \begin{bmatrix}
# 1 & 2 & 0 & 1 & 0 & 0 \\
# 2 & 1 & -1 & 0 & 1 & 0\\
# 3 & 1 & 1 & 0 & 0 & 1\\
# \end{bmatrix}
# \equiv F2-2F1\rightarrow F2\\
# \begin{bmatrix}
# 1 & 2 & 0 & 1 & 0 & 0 \\
# 0 & -3 & -1 & -2 & 1 & 0\\
# 3 & 1 & 1 & 0 & 0 & 1\\
# \end{bmatrix}
# \equiv F3-3F1\rightarrow F3\\
# \begin{bmatrix}
# 1 & 2 & 0 & 1 & 0 & 0 \\
# 0 & -3 & -1 & -2 & 1 & 0\\
# 0 & -5 & 1 & -3 & 0 & 1\\
# \end{bmatrix}
# \equiv F2/-3\rightarrow F2\\
# \begin{bmatrix}
# 1 & 2 & 0 & 1 & 0 & 0 \\
# 0 & 1 & 0.333 & 0.667 & -0.333 & 0\\
# 0 & -5 & 1 & -3 & 0 & 1\\
# \end{bmatrix}
# \equiv F3-(-5)*F2\rightarrow F3\\
# \begin{bmatrix}
# 1 & 2 & 0 & 1 & 0 & 0 \\
# 0 & 1 & 0.333 & 0.667 & -0.333 & 0\\
# 0 & 0 & 2.667 & 0.333 & -1.667 & 1\\
# \end{bmatrix}
# \equiv F3/2.667\rightarrow F3\\
# \begin{bmatrix}
# 1 & 2 & 0 & 1 & 0 & 0 \\
# 0 & 1 & 0.333 & 0.667 & -0.333 & 0\\
# 0 & 0 & 1 & 0.125 & -0.625 & 0.375\\
# \end{bmatrix}
# \equiv F2-0.333F3\rightarrow F2\\
# \begin{bmatrix}
# 1 & 2 & 0 & 1 & 0 & 0 \\
# 0 & 1 & 0 & 0.625 & -0.125 & -0.125\\
# 0 & 0 & 1 & 0.125 & -0.625 & 0.375\\
# \end{bmatrix}
# \equiv F1-2F2\rightarrow F1\\
# \begin{bmatrix}
# 1 & 0 & 0 & -0.25 & 0.25 & 0.25 \\
# 0 & 1 & 0 & 0.625 & -0.125 & -0.125\\
# 0 & 0 & 1 & 0.125 & -0.625 & 0.375\\
# \end{bmatrix}\\
# inversa=
# \begin{bmatrix}
# -0.25 & 0.25 & 0.25 \\
# 0.625 & -0.125 & -0.125\\
# 0.125 & -0.625 & 0.375\\
# \end{bmatrix}
# $$

# %% [markdown]
# ### c)

# %% [markdown]
# A continuación se muestra el proceso con Gauss-Jordan
# $$
# \begin{bmatrix}
# 1 & 1 & -1 & 1 & 1 & 0 & 0 & 0\\
# 1 & 2 & -4 & -2 & 0 & 1 & 0 & 0\\
# 2 & 1 & 1 & 5 & 0 & 0 & 1 & 0\\
# -1 & 0 & -2 & -4 & 0 & 0 & 0 & 1 \\
# \end{bmatrix}
# \equiv F2-F1\rightarrow F2\\
# \begin{bmatrix}
# 1 & 1 & -1 & 1 & 1 & 0 & 0 & 0\\
# 0 & 1 & -3 & 3 & -1 & 1 & 0 & 0\\
# 2 & 1 & 1 & 5 & 0 & 0 & 1 & 0\\
# -1 & 0 & -2 & -4 & 0 & 0 & 0 & 1 \\
# \end{bmatrix}
# \equiv F3-2F1\rightarrow F3\\
# \begin{bmatrix}
# 1 & 1 & -1 & 1 & 1 & 0 & 0 & 0\\
# 0 & 1 & -3 & 3 & -1 & 1 & 0 & 0\\
# 0 & -1 & 3 & 3 & -2 & 0 & 1 & 0\\
# -1 & 0 & -2 & -4 & 0 & 0 & 0 & 1 \\
# \end{bmatrix}
# \equiv F4-(-F1)\rightarrow F4\\
# \begin{bmatrix}
# 1 & 1 & -1 & 1 & 1 & 0 & 0 & 0\\
# 0 & 1 & -3 & 3 & -1 & 1 & 0 & 0\\
# 0 & -1 & 3 & 3 & -2 & 0 & 1 & 0\\
# 0& 1 & -3 & -3 & 1 & 0 & 0 & 1 \\
# \end{bmatrix}
# \equiv F3-(-F2)\rightarrow F3\\
# \begin{bmatrix}
# 1 & 1 & -1 & 1 & 1 & 0 & 0 & 0\\
# 0 & 1 & -3 & 3 & -1 & 1 & 0 & 0\\
# 0 & 0 & 0 & 0 & -2 & 0 & 1 & 0\\
# 0& 1 & -3 & -3 & 1 & 0 & 0 & 1 \\
# \end{bmatrix}
# $$
# La matriz tiene un determinante de cero, por lo que no se puede encontrar la inversa.

# %% [markdown]
# ### d)

# %% [markdown]
# A continuación se muestra el proceso con Gauss-Jordan
# $$
# \begin{bmatrix}
# 4 & 0 & 0 & 0 & 1 & 0 & 0 & 0\\
# 6 & 7 & 0 & 0 & 0 & 1 & 0 & 0\\
# 9 & 11 & 1 & 0 & 0 & 0 & 1 & 0\\
# 5 & 4 & 1 & 1 & 0 & 0 & 0 & 1\\
# \end{bmatrix}
# \equiv F1/4\rightarrow F1\\
# \begin{bmatrix}
# 1& 0 & 0 & 0 & 0.25 & 0 & 0 & 0\\
# 6 & 7 & 0 & 0 & 0 & 1 & 0 & 0\\
# 9 & 11 & 1 & 0 & 0 & 0 & 1 & 0\\
# 5 & 4 & 1 & 1 & 0 & 0 & 0 & 1\\
# \end{bmatrix}
# \equiv F2-6F1\rightarrow F2\\
# \begin{bmatrix}
# 1& 0 & 0 & 0 & 0.25 & 0 & 0 & 0\\
# 0 & 7 & 0 & 0 & -1.5 & 1 & 0 & 0\\
# 9 & 11 & 1 & 0 & 0 & 0 & 1 & 0\\
# 5 & 4 & 1 & 1 & 0 & 0 & 0 & 1\\
# \end{bmatrix}
# \equiv F3-9F1\rightarrow F3\\
# \begin{bmatrix}
# 1& 0 & 0 & 0 & 0.25 & 0 & 0 & 0\\
# 0 & 7 & 0 & 0 & -1.5 & 1 & 0 & 0\\
# 0 & 11 & 1 & 0 & -2.25 & 0 & 1 & 0\\
# 5 & 4 & 1 & 1 & 0 & 0 & 0 & 1\\
# \end{bmatrix}
# \equiv F4-5F1\rightarrow F4\\
# \begin{bmatrix}
# 1& 0 & 0 & 0 & 0.25 & 0 & 0 & 0\\
# 0 & 7 & 0 & 0 & -1.5 & 1 & 0 & 0\\
# 0 & 11 & 1 & 0 & -2.25 & 0 & 1 & 0\\
# 0 & 4 & 1 & 1 & -1.25 & 0 & 0 & 1\\
# \end{bmatrix}
# \equiv F2/7\rightarrow F2\\
# \begin{bmatrix}
# 1& 0 & 0 & 0 & 0.25 & 0 & 0 & 0\\
# 0 & 1 & 0 & 0 & -0.214 & 0.143 & 0 & 0\\
# 0 & 11 & 1 & 0 & -2.25 & 0 & 1 & 0\\
# 0 & 4 & 1 & 1 & -1.25 & 0 & 0 & 1\\
# \end{bmatrix}
# \equiv F3-11F2\rightarrow F3\\
# \begin{bmatrix}
# 1& 0 & 0 & 0 & 0.25 & 0 & 0 & 0\\
# 0 & 1 & 0 & 0 & -0.214 & 0.143 & 0 & 0\\
# 0 & 0 & 1 & 0 & 0.107 & -1.571 & 1 & 0\\
# 0 & 4 & 1 & 1 & -1.25 & 0 & 0 & 1\\
# \end{bmatrix}
# \equiv F4-4F2\rightarrow F4\\
# \begin{bmatrix}
# 1& 0 & 0 & 0 & 0.25 & 0 & 0 & 0\\
# 0 & 1 & 0 & 0 & -0.214 & 0.143 & 0 & 0\\
# 0 & 0 & 1 & 0 & 0.107 & -1.571 & 1 & 0\\
# 0 & 0 & 1 & 1 & -0.393 & -0.571 & 0 & 1\\
# \end{bmatrix}
# \equiv F4-F3\rightarrow F4\\
# \begin{bmatrix}
# 1& 0 & 0 & 0 & 0.25 & 0 & 0 & 0\\
# 0 & 1 & 0 & 0 & -0.214 & 0.143 & 0 & 0\\
# 0 & 0 & 1 & 0 & 0.107 & -1.571 & 1 & 0\\
# 0 & 0 & 0 & 1 & -0.5 & 1 & -1 & 1\\
# \end{bmatrix}
# $$
# $$
# matriz inversa=
# \begin{bmatrix}
# 0.25 & 0 & 0 & 0\\
# -0.214 & 0.143 & 0 & 0\\
# 0.107 & -1.571 & 1 & 0\\
# -0.5 & 1 & -1 & 1\\
# \end{bmatrix}
# $$

# %% [markdown]
# ## 3. Resuelva los sistemas lineales 4 x 4 que tienen la misma matriz de coeficientes.
# ![](tarea10.3.png)

# %% [markdown]
# Resolviendo el primer sistema de ecuaciones:
# $$
# \begin{bmatrix}
# 1 & -1 & 2 & -1 &|6\\
# 1 & 0 & -1 & 1 &|4\\
# 2 & 1 & 3 & -4 &|-2\\
# 0 & -1 & 1 & -1 &|5\\
# \end{bmatrix}
# \equiv F2-F1\rightarrow F2\\
# \begin{bmatrix}
# 1 & -1 & 2 & -1 &|6\\
# 0 & 1 & -3 & 2 &|-2\\
# 2 & 1 & 3 & -4 &|-2\\
# 0 & -1 & 1 & -1 &|5\\
# \end{bmatrix}
# \equiv F3-2F1\rightarrow F3\\
# \begin{bmatrix}
# 1 & -1 & 2 & -1 &|6\\
# 0 & 1 & -3 & 2 &|-2\\
# 0 & 3 & -1 & -2 &|-14\\
# 0 & -1 & 1 & -1 &|5\\
# \end{bmatrix}
# \equiv F3-3F2\rightarrow F3\\
# \begin{bmatrix}
# 1 & -1 & 2 & -1 &|6\\
# 0 & 1 & -3 & 2 &|-2\\
# 0 & 0 & 8 & -8 &|-8\\
# 0 & -1 & 1 & -1 &|5\\
# \end{bmatrix}
# \equiv F4+F2\rightarrow F4\\
# \begin{bmatrix}
# 1 & -1 & 2 & -1 &|6\\
# 0 & 1 & -3 & 2 &|-2\\
# 0 & 0 & 8 & -8 &|-8\\
# 0 & 0 & -2 & 1 &|3\\
# \end{bmatrix}
# \equiv F3/8\rightarrow F3\\
# \begin{bmatrix}
# 1 & -1 & 2 & -1 &|6\\
# 0 & 1 & -3 & 2 &|-2\\
# 0 & 0 & 1 & -1 &|-1\\
# 0 & 0 & -2 & 1 &|3\\
# \end{bmatrix}
# \equiv F4+2F3\rightarrow F4\\
# \begin{bmatrix}
# 1 & -1 & 2 & -1 &|6\\
# 0 & 1 & -3 & 2 &|-2\\
# 0 & 0 & 1 & -1 &|-1\\
# 0 & 0 & 0 & -1 &|1\\
# \end{bmatrix}
# \equiv F4/-1\rightarrow F4\\
# \begin{bmatrix}
# 1 & -1 & 2 & -1 &|6\\
# 0 & 1 & -3 & 2 &|-2\\
# 0 & 0 & 1 & -1 &|-1\\
# 0 & 0 & 0 & 1 &|-1\\
# \end{bmatrix}
# \equiv F3+F4\rightarrow F3\\
# \begin{bmatrix}
# 1 & -1 & 2 & -1 &|6\\
# 0 & 1 & -3 & 2 &|-2\\
# 0 & 0 & 1 & 0 &|-2\\
# 0 & 0 & 0 & 1 &|-1\\
# \end{bmatrix}\\
# resultado:\\
# x_4=-1\\
# x_3=-2\\
# x_2=-6\\
# x_1=3
# $$

# %% [markdown]
# Resolviendo el segundo sistema de ecuaciones:
# $$
# \begin{bmatrix}
# 1 & -1 & 2 & -1 &|1\\
# 1 & 0 & -1 & 1 &|1\\
# 2 & 1 & 3 & -4 &|2\\
# 0 & -1 & 1 & -1 &|-1\\
# \end{bmatrix}
# \equiv F2-F1\rightarrow F2\\
# \begin{bmatrix}
# 1 & -1 & 2 & -1 &|1\\
# 0 & 1 & -3 & 2 &|0\\
# 2 & 1 & 3 & -4 &|2\\
# 0 & -1 & 1 & -1 &|-1\\
# \end{bmatrix}
# \equiv F3-2F1\rightarrow F3\\
# \begin{bmatrix}
# 1 & -1 & 2 & -1 &|1\\
# 0 & 1 & -3 & 2 &|0\\
# 0 & 3 & -1 & -2 &|0\\
# 0 & -1 & 1 & -1 &|-1\\
# \end{bmatrix}
# \equiv F3-3F2\rightarrow F3\\
# \begin{bmatrix}
# 1 & -1 & 2 & -1 &|1\\
# 0 & 1 & -3 & 2 &|0\\
# 0 & 0 & 8 & -8 &|0\\
# 0 & -1 & 1 & -1 &|-1\\
# \end{bmatrix}
# \equiv F4+F2\rightarrow F4\\
# \begin{bmatrix}
# 1 & -1 & 2 & -1 &|1\\
# 0 & 1 & -3 & 2 &|0\\
# 0 & 0 & 8 & -8 &|0\\
# 0 & 0 & -2 & 1 &|-1\\
# \end{bmatrix}
# \equiv F3/8\rightarrow F3\\
# \begin{bmatrix}
# 1 & -1 & 2 & -1 &|1\\
# 0 & 1 & -3 & 2 &|0\\
# 0 & 0 & 1 & -1 &|0\\
# 0 & 0 & -2 & 1 &|-1\\
# \end{bmatrix}
# \equiv F4+2F3\rightarrow F4\\
# \begin{bmatrix}
# 1 & -1 & 2 & -1 &|1\\
# 0 & 1 & -3 & 2 &|0\\
# 0 & 0 & 1 & -1 &|0\\
# 0 & 0 & 0 & -1 &|-1\\
# \end{bmatrix}
# \equiv F4/-1\rightarrow F4\\
# \begin{bmatrix}
# 1 & -1 & 2 & -1 &|1\\
# 0 & 1 & -3 & 2 &|0\\
# 0 & 0 & 1 & -1 &|0\\
# 0 & 0 & 0 & 1 &|1\\
# \end{bmatrix}
# \equiv F3+F4\rightarrow F3\\
# \begin{bmatrix}
# 1 & -1 & 2 & -1 &|1\\
# 0 & 1 & -3 & 2 &|0\\
# 0 & 0 & 1 & 0 &|1\\
# 0 & 0 & 0 & 1 &|1\\
# \end{bmatrix}\\
# resultado:\\
# x_4=1\\
# x_3=1\\
# x_2=1\\
# x_1=1\\
# $$

# %% [markdown]
# ## 4. Encuentre los valores de A que hacen que la siguiente matriz sea singular.
# ![](tarea10.4.png)

# %% [markdown]
# A continuación vamos a reducir la matriz para obtener el valor de $\alpha$ necesario
# $$
# \begin{bmatrix}
# 1 & -1 & \alpha\\
# 2 & 2 & 1\\
# 0 & \alpha & -\frac{3}{2}
# \end{bmatrix}
# \equiv F2-2F1\rightarrow F2\\
# \begin{bmatrix}
# 1 & -1 & \alpha\\
# 0 & 4 & -2\alpha+1
# 0 & \alpha & -1.5
# \end{bmatrix}
# \equiv F2/4\rightarrow F2\\
# \begin{bmatrix}
# 1 & -1 & \alpha\\
# 0 & 1 & -0.5\alpha+0.25
# 0 & \alpha & -1.5
# \end{bmatrix}
# \equiv F3- \alpha F2 \rightarrow F3\\
# \begin{bmatrix}
# 1 & -1 & \alpha\\
# 0 & 1 & -0.5\alpha+0.25
# 0 & 0 & 0.5\alpha^2-1.5
# \end{bmatrix}
# $$
# por lo que debemos hacer cumplir $0.5\alpha^2-1.5=0$, si lo multiplicamos por 4 la ecuación queda $2\alpha^2-\alpha-6=0$, resolviendo a través de la fórmula general se obtiene:
# $$
# \alpha=2\\
# \alpha=-1.5
# $$

# %% [markdown]
# ## Resuelva los siguientes sistemas lineales
# ![](tarea10.5.png)

# %% [markdown]
# ### a)
# a continuación se realizará la sustitución hacia adelante
# $$
# a=2\\
# 2a+b=-1\\
# -a+c=1\\
# b=-1-4=-5\\
# c=1+2=3\\
# \begin{bmatrix}
# a\\
# b\\
# c\\
# \end{bmatrix}
# =
# \begin{bmatrix}
# 2\\
# -5\\
# 3\\
# \end{bmatrix}
# $$
# continuando con la sustitución hacia atrás
# $$
# 3z=3\\
# z=1\\
# -2y+z=-2\\
# y=3\\
# 2x+3y-z=2\\
# x=-3\\
# \begin{bmatrix}
# x\\
# y\\
# z\\
# \end{bmatrix}
# =
# \begin{bmatrix}
# -3\\
# 3\\
# 1\\
# \end{bmatrix}
# $$

# %% [markdown]
# ### b)
# Se realiza la sustitución hacia adelante
# $$
# 2a=-1\\
# a=-\frac{1}{2}\\
# -a+b=3\\
# b=\frac{5}{2}\\
# 3a+3b-c=0\\
# c=\frac{7}{2}
# \begin{bmatrix}
# a\\
# b\\
# c\\
# \end{bmatrix}
# =
# \begin{bmatrix}
# -\frac{1}{2}\\
# \frac{5}{2}\\
# \frac{7}{2}\\
# \end{bmatrix}
# $$
# Se realiza la sustitución hacia atrás
# $$
# z=\frac{7}{2}\\
# y+2z=\frac{5}{2}\\
# y=-\frac{9}{2}\\
# x+y+z=\frac{1}{2}\\
# x=\frac{1}{2}
# \begin{bmatrix}
# x\\
# y\\
# z\\
# \end{bmatrix}
# =
# \begin{bmatrix}
# \frac{1}{2}\\
# -\frac{9}{2}\\
# \frac{7}{2}\\
# \end{bmatrix}
# $$

# %% [markdown]
# ## 6. Factorice las siguientes matrices en la descomposición LU mediante el agoritmo de factorización LU con $l_{ii}=1$ para todas las i.
# ![](tarea10.6.png)

# %% [markdown]
# ### a)
# $$
# \begin{bmatrix}
# 2 & -1 & 1\\
# 3 & 3 & 9\\
# 3 & 3 & 5\\
# \end{bmatrix}
# \equiv F2-1.5F1\rightarrow F2\\
# \begin{bmatrix}
# 2 & -1 & 1\\
# 0 & 4.5 & 7.5\\
# 3 & 3 & 5\\
# \end{bmatrix}
# \equiv F3-1.5F1\rightarrow F3\\
# \begin{bmatrix}
# 2 & -1 & 1\\
# 0 & 4.5 & 7.5\\
# 0 & 4.5 & 3.5\\
# \end{bmatrix}
# \equiv F3-F2\rightarrow F3\\
# \begin{bmatrix}
# 2 & -1 & 1\\
# 0 & 4.5 & 7.5\\
# 0 & 0 & -4\\
# \end{bmatrix}\\
# por lo tanto:\\
# U=\begin{bmatrix}
# 2 & -1 & 1\\
# 0 & 4.5 & 7.5\\
# 0 & 0 & -4\\
# \end{bmatrix}\\
# L=\begin{bmatrix}
# 1 & 0 & 0\\
# 1.5 & 0 & 0\\
# 1.5 & 1 & 0\\
# \end{bmatrix}\\
# $$

# %% [markdown]
# ### b)
# $$
# \begin{bmatrix}
# 1.012 & -2.132 & 3.104\\
# -2.132 & 4.096 & -7.013\\
# 3.104 & -7.013 & 0.014\\
# \end{bmatrix}
# \equiv F2-(-2.107)F1\rightarrow F2\\
# \begin{bmatrix}
# 1.012 & -2.132 & 3.104\\
# 0 & -0.396 & -0.474\\
# 3.104 & -7.013 & 0.014\\
# \end{bmatrix}
# \equiv F3-(3.067)F1\rightarrow F3\\
# \begin{bmatrix}
# 1.012 & -2.132 & 3.104\\
# 0 & -0.396 & -0.474\\
# 0 & -0.474 & -9.507\\
# \end{bmatrix}
# \equiv F3-(1.198)F2\rightarrow F3\\
# \begin{bmatrix}
# 1.012 & -2.132 & 3.104\\
# 0 & -0.396 & -0.474\\
# 0 & 0 & -8.939\\
# \end{bmatrix}\\
# por lo tanto:\\
# U=
# \begin{bmatrix}
# 1.012 & -2.132 & 3.104\\
# 0 & -0.396 & -0.474\\
# 0 & 0 & -8.939\\
# \end{bmatrix}\\
# L=
# \begin{bmatrix}
# 1 $ 0 & 0\\
# -2.107 & 1 & 0\\
# 3.067 & 1.198 & 1\\
# \end{bmatrix}\\
# $$

# %% [markdown]
# ### c)
# $$
# \begin{bmatrix}
# 2 & 0 & 0 & 0\\
# 1 & 1.5 & 0 & 0\\
# 0 & -3 & 0.5 & 0\\
# 2 & -2 & 1 & 1\\
# \end{bmatrix}
# \equiv F2-0.5F1\rightarrow F2\\
# \begin{bmatrix}
# 2 & 0 & 0 & 0\\
# 0 & 1.5 & 0 & 0\\
# 0 & -3 & 0.5 & 0\\
# 2 & -2 & 1 & 1\\
# \end{bmatrix}
# \equiv F4-1F1\rightarrow F4\\
# \begin{bmatrix}
# 2 & 0 & 0 & 0\\
# 0 & 1.5 & 0 & 0\\
# 0 & -3 & 0.5 & 0\\
# 0 & -2 & 1 & 1\\
# \end{bmatrix}
# \equiv F3-(-2)F2\rightarrow F3\\
# \begin{bmatrix}
# 2 & 0 & 0 & 0\\
# 0 & 1.5 & 0 & 0\\
# 0 & 0 & 0.5 & 0\\
# 0 & -2 & 1 & 1\\
# \end{bmatrix}
# \equiv F4-(-1.333)F2\rightarrow F4\\
# \begin{bmatrix}
# 2 & 0 & 0 & 0\\
# 0 & 1.5 & 0 & 0\\
# 0 & 0 & 0.5 & 0\\
# 0 & 0 & 1 & 1\\
# \end{bmatrix}
# \equiv F4-2F3\rightarrow F4\\
# \begin{bmatrix}
# 2 & 0 & 0 & 0\\
# 0 & 1.5 & 0 & 0\\
# 0 & 0 & 0.5 & 0\\
# 0 & 0 & 0 & 1\\
# \end{bmatrix}\\
# U=\begin{bmatrix}
# 2 & 0 & 0 & 0\\
# 0 & 1.5 & 0 & 0\\
# 0 & 0 & 0.5 & 0\\
# 0 & 0 & 0 & 1\\
# \end{bmatrix}\\
# L=\begin{bmatrix}
# 1 & 0 & 0 & 0\\
# 0.5 & 1 & 0 & 0\\
# 0 & -2 & 1 & 0\\
# 1 & -1.333 & 2 & 1\\
# \end{bmatrix}\\
# $$

# %% [markdown]
# ### d)
# $$
# \begin{bmatrix}
# 2.1756 & 4.0231 & -2.1732 & 5.1967\\
# -4.0231 & 6.0000 & 0 & 1.1973\\
# -1.0000 & -5.2107 & 1.1111 & 0\\
# 6.0235 & 7.0000 & 0 & -4.1561\\
# \end{bmatrix}
# \equiv F2-(-1.849)F1\rightarrow F2\\
# \begin{bmatrix}
# 2.1756 & 4.0231 & -2.1732 & 5.1967\\
# 0 & 13.439 & -4.019 & 10.807\\
# -1.0000 & -5.2107 & 1.1111 & 0\\
# 6.0235 & 7.0000 & 0 & -4.1561\\
# \end{bmatrix}
# \equiv F3-(-0.460)F1\rightarrow F3\\
# \begin{bmatrix}
# 2.1756 & 4.0231 & -2.1732 & 5.1967\\
# 0 & 13.439 & -4.019 & 10.807\\
# 0& -3.362 & 0.112 & 2.389\\
# 6.0235 & 7.0000 & 0 & -4.1561\\
# \end{bmatrix}
# \equiv F4-(2.769)F1\rightarrow F4\\
# \begin{bmatrix}
# 2.1756 & 4.0231 & -2.1732 & 5.1967\\
# 0 & 13.439 & -4.019 & 10.807\\
# 0& -3.362 & 0.112 & 2.389\\
# 0 & -4.139 & 6.017 & -18.544\\
# \end{bmatrix}
# \equiv F3-(-0.250)F1\rightarrow F3\\
# \begin{bmatrix}
# 2.1756 & 4.0231 & -2.1732 & 5.1967\\
# 0 & 13.439 & -4.019 & 10.807\\
# 0& 0 & -0.893 & 5.092\\
# 0 & -4.139 & 6.017 & -18.544\\
# \end{bmatrix}
# \equiv F4-(-0.308)F2\rightarrow F4\\
# \begin{bmatrix}
# 2.1756 & 4.0231 & -2.1732 & 5.1967\\
# 0 & 13.439 & -4.019 & 10.807\\
# 0& 0 & -0.893 & 5.092\\
# 0 & 0 & 4.779 & -15.216\\
# \end{bmatrix}
# \equiv F4-(-5.352)F3\rightarrow F4\\
# \begin{bmatrix}
# 2.1756 & 4.0231 & -2.1732 & 5.1967\\
# 0 & 13.439 & -4.019 & 10.807\\
# 0& 0 & -0.893 & 5.092\\
# 0 & 0 & 0 & 12.036\\
# \end{bmatrix}\\
# U=\begin{bmatrix}
# 2.1756 & 4.0231 & -2.1732 & 5.1967\\
# 0 & 13.439 & -4.019 & 10.807\\
# 0& 0 & -0.893 & 5.092\\
# 0 & 0 & 0 & 12.036\\
# \end{bmatrix}\\
# L=\begin{bmatrix}
# 1 & 0 & 0 & 0\\
# -1.849 & 1 & 0 & 0\\
# -0.460 & -0.250 & 1 & 0\\
# 2.769 & -0.308 & -5.352 & 1\\
# \end{bmatrix}\\
# $$

# %% [markdown]
# ## 7. Modifique el algoritmo de eliminación gaussiana de tal forma que se pueda utilizar para resolver un sistema lineal usando descomposición LU y a continuación, resuelva los siguientes sistemas lineales.
# ![](tarea10.7.png)

# %%
import numpy as np

def resolver_sistema_lu(A, b):
    def descomposicion_lu(A):
        n = A.shape[0]
        L = np.eye(n)
        U = A.astype(float).copy()
        for i in range(n):
            for j in range(i+1, n):
                factor = U[j, i] / U[i, i]
                L[j, i] = factor
                U[j, :] -= factor * U[i, :]
        return L, U

    def sustitucion_adelante(L, b):
        n = L.shape[0]
        y = np.zeros(n)
        for i in range(n):
            y[i] = (b[i] - np.dot(L[i, :i], y[:i])) / L[i, i]
        return y

    def sustitucion_atras(U, y):
        n = U.shape[0]
        x = np.zeros(n)
        for i in range(n-1, -1, -1):
            x[i] = (y[i] - np.dot(U[i, i+1:], x[i+1:])) / U[i, i]
        return x

    L, U = descomposicion_lu(A)
    y = sustitucion_adelante(L, b)
    x = sustitucion_atras(U, y)
    return x

# %% [markdown]
# ### a)

# %%
A = np.array([[2,-1,1],[3,3,9],[3,3,5]])
b = np.array([-1,0,4])
solucion = resolver_sistema_lu(A, b)
print("\nSolución del sistema:")
print(solucion)
# Out:
# Solución del sistema:
# [ 1.  2. -1.]

# %% [markdown]
# ### b)

# %%
A = np.array([[1.012,-2.132,3.104],[-2.132,4.096,-7.013],[3.104,-7.013,0.014]])
b = np.array([1.984,-5.049,-3.895])
solucion = resolver_sistema_lu(A, b)
print("\nSolución del sistema:")
print(solucion)
# Out:
# Solución del sistema:
# [1. 1. 1.]

# %% [markdown]
# ### c)

# %%
A = np.array([[2,0,0,0],[1,1.5,0,0],[0,-3,0.5,0],[2,-2,1,1]])
b = np.array([3,4.5,-6.6,0.8])
solucion = resolver_sistema_lu(A, b)
print("\nSolución del sistema:")
print(solucion)
# Out:
# Solución del sistema:
# [ 1.5  2.  -1.2  3. ]

# %% [markdown]
# ### d)

# %%
A = np.array([[2.1756,4.0231,-2.1732,5.1967],[-4.0231,6,0,1.1973],[-1,-5.2107,1.1111,0],[6.0235,7,0,-4.1561]])
b = np.array([17.102,-6.1593,3.0004,0])
solucion = resolver_sistema_lu(A, b)
print("\nSolución del sistema:")
print(solucion)
# Out:
# Solución del sistema:
# [2.9398512  0.0706777  5.67773512 4.37981223]
